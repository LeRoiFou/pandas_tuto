# %% [markdown]
# # Fillna()

# %%
import pandas as pd
from skimpy import skim

# %%
df = pd.read_excel('data/Fillna.xlsx', sheet_name='Feuil1')

# %%
df
# Out:
#            Vendeur  Article       Date  Montant
# 0       Jet Claire  AXT1247 2023-05-14      NaN
# 1      Kaman Medhi  AXT1222 2023-06-25   4000.0
# 2      Kanar Fouad  AXT1245 2023-06-24   8600.0
# 3       Jet Claire      NaN        NaT   6400.0
# 4      Kaman Medhi  AXT1231 2023-05-29   4200.0
# 5     Lile Maurice  AXT1231 2023-04-17   5700.0
# 6       Jet Claire  AXT1224 2023-04-03  14000.0
# 7      Kaman Medhi      NaN        NaT      NaN
# 8       Jet Claire  AXT1225 2023-06-02   3400.0
# 9      Kanar Fouad  AXT1244 2023-06-22  11000.0
# 10    Lile Maurice  AXT1220 2023-05-29   6700.0
# 11      Jet Claire  AXT1220 2023-04-02   3500.0
# 12   Fortune Alain  AXT1228 2023-04-18   9000.0
# 13  Galls Charline      NaN 2023-04-10  11000.0
# 14   Gature Emilie  AXT1222 2023-05-12   3500.0
# 15        Gori Ali  AXT1233        NaT   6800.0
# 16     Guet Pierre  AXT1231 2023-04-02   5700.0
# 17        Gori Ali      NaN        NaT   6800.0
# 18     Guet Pierre  AXT1237 2023-05-29  11300.0
# ...

# %%
skim(df)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ Dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 26     │ │ string      │ 2     │                                                          │
# │ │ Number of columns │ 4      │ │ datetime64  │ 1     │                                                          │
# │ └───────────────────┴────────┘ │ float64     │ 1     │                                                          │
# ...

# %% [markdown]
# ## Remplacement des valeurs vides par un texte

# %%
df.fillna('soon')
# Out:
#            Vendeur  Article                 Date  Montant
# 0       Jet Claire  AXT1247  2023-05-14 00:00:00     soon
# 1      Kaman Medhi  AXT1222  2023-06-25 00:00:00   4000.0
# 2      Kanar Fouad  AXT1245  2023-06-24 00:00:00   8600.0
# 3       Jet Claire     soon                 soon   6400.0
# 4      Kaman Medhi  AXT1231  2023-05-29 00:00:00   4200.0
# 5     Lile Maurice  AXT1231  2023-04-17 00:00:00   5700.0
# 6       Jet Claire  AXT1224  2023-04-03 00:00:00  14000.0
# 7      Kaman Medhi     soon                 soon     soon
# 8       Jet Claire  AXT1225  2023-06-02 00:00:00   3400.0
# 9      Kanar Fouad  AXT1244  2023-06-22 00:00:00  11000.0
# 10    Lile Maurice  AXT1220  2023-05-29 00:00:00   6700.0
# 11      Jet Claire  AXT1220  2023-04-02 00:00:00   3500.0
# 12   Fortune Alain  AXT1228  2023-04-18 00:00:00   9000.0
# 13  Galls Charline     soon  2023-04-10 00:00:00  11000.0
# 14   Gature Emilie  AXT1222  2023-05-12 00:00:00   3500.0
# ...
